# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
import json

# %matplotlib inline

# %%
api_key = ''

# %%
endpoint = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# %%
params = {
    'key': api_key, 
    'location': '36.186836,-86.8253295', 
    'radius': 50000,
    'type': 'car_wash'
}

# %%
response = requests.get(endpoint, params = params)
response
# Out:
# <Response [200]>

# %%
response.url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyAnXkySO5Kft9Qsr83VNb0s-N9iqfxyMgw&location=36.186836%2C-86.8253295&radius=50000&type=car_wash'

# %%
res = response.json()
res
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJL4PrxAcSvbK2VDFO3wfF-bT9pwo5SDcPoxO5EVmIa_IB9-iUoih23UItiD0N-OVALfKSLGx4k7GFP6Jxi4aQt8AX6ZVG19pbu9S0xpdfT4qolvw0gj9cB04vZLitjPWG_Qx4uteHhE8KJhEIWVK-e1zrj7ArU9mEeOiVAxvTZt2UNHm0oxO2czO8SwRYDR2CAWTReRMOCWwn6r1DoCDpxg-p40NMfYCJQ3Ew_iRJMVnqi7FGCHDO0QlPF0gukE5fYNowPpJGuJ3r8YGNc465FWViqWi1LCaLTSJoy4WPwGyEpQLVDbTE0yoEKHDEBFCTxksDbKlyq--dlYZCbEC2NGsQWqMXKLxGx5Bkp_Q5AFNgT0lSQwmWCl2DAsbxj27UOalu9ZkpBNd-nwzgqKxiatE7J06LqJD_9HnlSJKV6QqtEH0LnsFTuTw',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1459071, 'lng': -86.6695538},
#     'viewport': {'northeast': {'lat': 36.1474684302915,
#       'lng': -86.6681621197085},
#      'southwest': {'lat': 36.1447704697085, 'lng': -86.6708600802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Executive Travel & Parking',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 336,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117004174226915650348">Executive Travel &amp; Parking</a>'],
#      'photo_reference': 'ATtYBwKAL-T-ydXaI33jfbvc0UlopGt4-X0Udyx-W-hagoBdLYYprFnrOedNGP8j3dCMCJ4ypbs0wO38eOPfD_FO_ry0rOWOpTKc4zKwf1aZLwIwQIV863bjWSTWe9SlT5tKWc3kfg79KtG0O7thh2Z0SPEWXA-s-SV5vSUgcJFUPAk_Ey6Z',
#      'width': 900}],
#    'place_id': 'ChIJR0VEeVtpZIgRlf9l36xuy9U',
#    'plus_code': {'compound_code': '48WJ+95 Nashville, TN, USA',
#     'global_code': '868M48WJ+95'},
#    'rating': 4.4,
#    'reference': 'ChIJR0VEeVtpZIgRlf9l36xuy9U',
#    'scope': 'GOOGLE',
#    'types': ['car_wash',
#     'parking',
#     'travel_agency',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 84,
#    'vicinity': '616 Royal Parkway, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.3050034, 'lng': -86.61690019999999},
#     'viewport': {'northeast': {'lat': 36.3064100802915,
#       'lng': -86.6155547697085},
#      'southwest': {'lat': 36.3037121197085, 'lng': -86.6182527302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'bp',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJH5tPnitHZIgRpdkId_9EylE',
#    'plus_code': {'compound_code': '894M+26 Hendersonville, TN, USA',
#     'global_code': '868M894M+26'},
#    'rating': 3.9,
#    'reference': 'ChIJH5tPnitHZIgRpdkId_9EylE',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'finance',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 42,
#    'vicinity': '157 West Main Street, Hendersonville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1529966, 'lng': -86.79500139999999},
#     'viewport': {'northeast': {'lat': 36.1543133302915,
#       'lng': -86.79371471970848},
#      'southwest': {'lat': 36.15161536970851, 'lng': -86.7964126802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Shur Brite Hi Speed Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117069453246582311316">Erika Iversen</a>'],
#      'photo_reference': 'ATtYBwLAqyuIvtmm0QLNdlC5KU_nO6Wsw8TAeELKBV_h1JkW-uArSmF_TZdBskoblOE5n3LK5XdsrNi-5NNVt3tzI1stkLHejnlCYAVjXM1slS1XoXGuRYbQdd0r-NNRBQHv74kyklf19zM4SG9ZiZsMGw32T_ONQF-nNNRANLOmRUHkxKve',
#      'width': 4128}],
#    'place_id': 'ChIJwxAiEpNmZIgRRTcmOxR_jic',
#    'plus_code': {'compound_code': '5633+5X Nashville, TN, USA',
#     'global_code': '868M5633+5X'},
#    'rating': 3.6,
#    'reference': 'ChIJwxAiEpNmZIgRRTcmOxR_jic',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 87,
#    'vicinity': '1713 West End Avenue, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 35.9876422, 'lng': -86.545082},
#     'viewport': {'northeast': {'lat': 35.9890665802915,
#       'lng': -86.5437881197085},
#      'southwest': {'lat': 35.9863686197085, 'lng': -86.54648608029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Mister Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114039309923614244538">Ebey Soman</a>'],
#      'photo_reference': 'ATtYBwIXiVgv-auHuJTHaV6Af7eNm7d4kgE73wfzJoCvRZKRkVp2Xu3rdcdC8Hvi1VylNP_sD1rCiPfCmEovvjqbz4VDnnpvelNwc7racNnH0XnjYWuAci3E1JN3FQxbMaxHFttxBt7q5ZuW3b4fRN1h4FmPLU3tZmiZTscJKi0S9fYZlZwT',
#      'width': 4032}],
#    'place_id': 'ChIJNRKdU-PlQIYRL3tQKfT4I9A',
#    'plus_code': {'compound_code': 'XFQ3+3X Smyrna, TN, USA',
#     'global_code': '867MXFQ3+3X'},
#    'rating': 3.8,
#    'reference': 'ChIJNRKdU-PlQIYRL3tQKfT4I9A',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 536,
#    'vicinity': '1200 Needham Drive, Smyrna'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1385861, 'lng': -86.85729479999999},
#     'viewport': {'northeast': {'lat': 36.1399533302915,
#       'lng': -86.85607046970848},
#      'southwest': {'lat': 36.13725536970851, 'lng': -86.85876843029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'White Bridge Auto Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100264802637223051002">White Bridge Auto Wash</a>'],
#      'photo_reference': 'ATtYBwIt6nYjOVgkih92ZQ8hDfVw-xaQBUuFrPcOeCMlb1HtewVGNVDQ1R_qC9OZF4NCuV7QzMr1E2wFKWR_FEdd9XMLsjNL5L_sGtKtJgBeYqudkjmF2AGMZpK6QvsKpo8c7Fk9U5eux3OQRtzz2UyxBIDrBzhWAM7XggFCop5_YNqOt0A-',
#      'width': 6720}],
#    'place_id': 'ChIJ38S2nX5hZIgRp-xOUYE959U',
#    'plus_code': {'compound_code': '44QV+C3 Nashville, TN, USA',
#     'global_code': '868M44QV+C3'},
#    'rating': 4,
#    'reference': 'ChIJ38S2nX5hZIgRp-xOUYE959U',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 386,
#    'vicinity': '212 White Bridge Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1094913, 'lng': -86.92302260000001},
#     'viewport': {'northeast': {'lat': 36.11083788029151,
#       'lng': -86.92160506970849},
#      'southwest': {'lat': 36.10813991970851, 'lng': -86.92430303029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'bp',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103722724296646027601">Philip Roberts</a>'],
#      'photo_reference': 'ATtYBwIx_uvW2C2YS0KmbZVryzXTIpG94BNa_dQsdGhitWfc12LiERqS_mW7X4wb-vguSBTClei00-67--NX12lLWdFqtqmdBZ0lQ1pF5wiEnurLEpq7r-iDM6Pk_NBivPFRhQFFyAaU6ULT-mgG5rIlryqnVfWvE4j7mawMpxy17NgBz9Jy',
#      'width': 3024}],
#    'place_id': 'ChIJFQFzW8eJZIgRfkfHFqG95nA',
#    'plus_code': {'compound_code': '435G+QQ Nashville, TN, USA',
#     'global_code': '868M435G+QQ'},
#    'rating': 3.8,
#    'reference': 'ChIJFQFzW8eJZIgRfkfHFqG95nA',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'finance',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 62,
#    'vicinity': '629 Old Hickory Boulevard, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.01606259999999, 'lng': -86.6167019},
#     'viewport': {'northeast': {'lat': 36.01736288029149,
#       'lng': -86.61536936970847},
#      'southwest': {'lat': 36.01466491970849, 'lng': -86.6180673302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'D & T Truck Wash & Repair',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ73wZafRyZIgRfmK44CPMMjU',
#    'plus_code': {'compound_code': '298M+C8 La Vergne, TN, USA',
#     'global_code': '868M298M+C8'},
#    'rating': 4.5,
#    'reference': 'ChIJ73wZafRyZIgRfmK44CPMMjU',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '936 Firestone Parkway, La Vergne'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1838028, 'lng': -86.6100052},
#     'viewport': {'northeast': {'lat': 36.1852091802915,
#       'lng': -86.60862706970849},
#      'southwest': {'lat': 36.1825112197085, 'lng': -86.61132503029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'bp',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJb6-L6O9qZIgRjxlkKUwR5Vs',
#    'plus_code': {'compound_code': '59MQ+GX Nashville, TN, USA',
#     'global_code': '868M59MQ+GX'},
#    'rating': 3.1,
#    'reference': 'ChIJb6-L6O9qZIgRjxlkKUwR5Vs',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'convenience_store',
#     'finance',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': '5400 Old Hickory Boulevard, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.0861279, 'lng': -86.64864829999999},
#     'viewport': {'northeast': {'lat': 36.0873841802915,
#       'lng': -86.64728996970848},
#      'southwest': {'lat': 36.08468621970851, 'lng': -86.6499879302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'bp',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111927045270163458579">bp</a>'],
#      'photo_reference': 'ATtYBwIWL3A1E-GNw_sVZ0xsa3dGJ23zAO754_V-46gshywvS9-89F9mhbhppLfsidrORkmJd_UK2raCeooT7L2ZZVzmQ4MhIjaxf3IViHp0lkjAbOlnTmdaH8aexPYvzRp0fuFJPxG0lVgy4tJ9S2QD4ZOBasxRRxENud41UNhuGPHcUyXh',
#      'width': 2000}],
#    'place_id': 'ChIJtx8PUy5sZIgRF1GpgdcltD4',
#    'plus_code': {'compound_code': '39P2+FG Nashville, TN, USA',
#     'global_code': '868M39P2+FG'},
#    'rating': 3.2,
#    'reference': 'ChIJtx8PUy5sZIgRF1GpgdcltD4',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'finance',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '2301 Murfreesboro Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.15665730000001, 'lng': -86.8069031},
#     'viewport': {'northeast': {'lat': 36.1581096802915,
#       'lng': -86.8056143697085},
#      'southwest': {'lat': 36.1554117197085, 'lng': -86.8083123302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'Shell',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107299917176740102908">Arun Adhikari</a>'],
#      'photo_reference': 'ATtYBwIMjJ69P8mHlrxp6PnFmn_G34ooSY7KeDdvkb2qdmA8ftdxyZvmecjW7GyEgSgjGOV14fToAmPkcHKkEykLf9C8gmKR0rCjlWQDAqgGoiu9yPZAG7fxTSTlxtcFmxLX0oAK7XN-GekTMriI0uRuI_S0v9KpCE81u14XZ8nYvwzx3kIs',
#      'width': 4160}],
#    'place_id': 'ChIJ3T24tMBmZIgRrCnQgt4c1sA',
#    'plus_code': {'compound_code': '554V+M6 Nashville, TN, USA',
#     'global_code': '868M554V+M6'},
#    'price_level': 2,
#    'rating': 3.6,
#    'reference': 'ChIJ3T24tMBmZIgRrCnQgt4c1sA',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'convenience_store',
#     'finance',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 104,
#    'vicinity': '2112 Charlotte Avenue, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2086752, 'lng': -86.778131},
#     'viewport': {'northeast': {'lat': 36.2100344302915,
#       'lng': -86.77672466970849},
#      'southwest': {'lat': 36.2073364697085, 'lng': -86.7794226302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'Shell',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100959308898530397111">RICK SYKES</a>'],
#      'photo_reference': 'ATtYBwJWzz7jjL-WhCE_QAiBoILqOWcNOz37ayP3DmwJS4_F9uN6vMtOpLqGz3Bmi_BkR_5qs3SHXllSfSZfKhmFnqDJ7XmuZQxsQEzBDqIKbvgMXTImxH7sa23HiERO3TGmqWMAEuMjz5qI-9ISLew_oQl5KXDnwqwVZCg8h7vgOyuGwRMj',
#      'width': 4032}],
#    'place_id': 'ChIJYbaIyZxnZIgRi8tU1uLXxXM',
#    'plus_code': {'compound_code': '665C+FP Nashville, TN, USA',
#     'global_code': '868M665C+FP'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJYbaIyZxnZIgRi8tU1uLXxXM',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'convenience_store',
#     'finance',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': '2312 Brick Church Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.14767760000001, 'lng': -86.7926466},
#     'viewport': {'northeast': {'lat': 36.1490094302915,
#       'lng': -86.7911542697085},
#      'southwest': {'lat': 36.1463114697085, 'lng': -86.7938522302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Auto Spa of Nashville',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100103480736009447054">Gulch Auto Spa</a>'],
#      'photo_reference': 'ATtYBwK5oV1_-dQFLdhNOSWhhxxwntPUjnjEDP9NqjQ8-9qlCtO6dNGfpvqRJ0mg_UjSwA_F_H9wrH_EkV8-GVe1p8Q0t11G_jyGJ_h7cU0H_p-Jx_HTNiyz-2hporeZFJEPP_IVGulqQ5gRQOjGSc7at4hRu3mCvJzPX6IR2dM0Ugms8mUR',
#      'width': 4032}],
#    'place_id': 'ChIJ_RaGsoxmZIgRFIZuHP8uwOs',
#    'plus_code': {'compound_code': '46X4+3W Nashville, TN, USA',
#     'global_code': '868M46X4+3W'},
#    'rating': 4,
#    'reference': 'ChIJ_RaGsoxmZIgRFIZuHP8uwOs',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 35,
#    'vicinity': '55 Music Square East, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2024493, 'lng': -86.73937649999999},
#     'viewport': {'northeast': {'lat': 36.2038522302915,
#       'lng': -86.73797971970848},
#      'southwest': {'lat': 36.2011542697085, 'lng': -86.7406776802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Mister Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3072,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117081526753059004723">Sara Jacobs</a>'],
#      'photo_reference': 'ATtYBwKt9aSjO_LbTSKHFOF2-AYc8kGbIo8f1qZVBw97pSexb7P7-y-guxNM47xcay3sLf4HxMbuh8njH47_rH2VBs1SjTGzpCuri2Z2q4u0bBJYO6FRKFyl4u_wF-VHT2tfElBzwSWzv2aHey03dYAOq6ivyzQoFE38DHhrL2CQpDZHl6dK',
#      'width': 4096}],
#    'place_id': 'ChIJmyXqKApoZIgRxMU9cTsWbD4',
#    'plus_code': {'compound_code': '6726+X6 Nashville, TN, USA',
#     'global_code': '868M6726+X6'},
#    'rating': 3.9,
#    'reference': 'ChIJmyXqKApoZIgRxMU9cTsWbD4',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 382,
#    'vicinity': '2831 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2431182, 'lng': -86.75753019999999},
#     'viewport': {'northeast': {'lat': 36.2445728302915,
#       'lng': -86.7561588697085},
#      'southwest': {'lat': 36.24187486970851, 'lng': -86.7588568302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Camel Express Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1729,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118263392095276129367">Camel Express Car Wash</a>'],
#      'photo_reference': 'ATtYBwJaj4e0VLxLb0QTTdBl3CES3QCv-hVvPKZFaAl4Md7LD-uAaI_Ry9p5z5ONOqq8hEOSBIXZ2SFoYrDaGTUnRS-vRP2R9brmO9s4fvFB9m6LoAf-U8B6q1q0la0DC0XwZs0yMPd2zPkL18huL2mWZN2Wdodi6BmBkl6rfd01YvTqgpXr',
#      'width': 3072}],
#    'place_id': 'ChIJNc2csDVkZIgRxd7SJJbWZSg',
#    'plus_code': {'compound_code': '66VR+6X Nashville, TN, USA',
#     'global_code': '868M66VR+6X'},
#    'rating': 4.4,
#    'reference': 'ChIJNc2csDVkZIgRxd7SJJbWZSg',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 353,
#    'vicinity': '3430 Doverside Drive, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1173922, 'lng': -86.92283069999999},
#     'viewport': {'northeast': {'lat': 36.1186126302915,
#       'lng': -86.92135306970849},
#      'southwest': {'lat': 36.1159146697085, 'lng': -86.92405103029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'Shell',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJKwiwL5WJZIgRbblNzrQkcHI',
#    'plus_code': {'compound_code': '438G+XV Nashville, TN, USA',
#     'global_code': '868M438G+XV'},
#    'price_level': 2,
#    'rating': 3.5,
#    'reference': 'ChIJKwiwL5WJZIgRbblNzrQkcHI',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'convenience_store',
#     'finance',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': '7354 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.0839362, 'lng': -86.7271967},
#     'viewport': {'northeast': {'lat': 36.0852801302915,
#       'lng': -86.7258458697085},
#      'southwest': {'lat': 36.0825821697085, 'lng': -86.7285438302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Mister Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101171100798988839208">Paul King</a>'],
#      'photo_reference': 'ATtYBwKYEXuiBWg_hGRqTp5P3TRzS52bnh6Am6B8mP0eoX7ZAnpQFiUGdPKXHhG9ErCTq4_OAuzVLJPxJAiaSHaS8MhOLTz8ikADyJtrrLGnP5iIHcF9vT_I7hfn2lELhtMkDw9qWND0VHTcVq9v8x_LdikxvN379z3GUSFZgWClfsXb_S_u',
#      'width': 4032}],
#    'place_id': 'ChIJlwRoGpxvZIgRp2nLwtOnqEI',
#    'plus_code': {'compound_code': '37MF+H4 Nashville, TN, USA',
#     'global_code': '868M37MF+H4'},
#    'rating': 4.4,
#    'reference': 'ChIJlwRoGpxvZIgRp2nLwtOnqEI',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 296,
#    'vicinity': '4024 Nolensville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.07754320000001, 'lng': -86.7315785},
#     'viewport': {'northeast': {'lat': 36.0789025302915,
#       'lng': -86.73018346970849},
#      'southwest': {'lat': 36.0762045697085, 'lng': -86.73288143029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Premier Mobile Detailing',
#    'place_id': 'ChIJVVVVVYVvZIgRM7wBykd7DHY',
#    'rating': 4.5,
#    'reference': 'ChIJVVVVVYVvZIgRM7wBykd7DHY',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.0739327, 'lng': -86.9213595},
#     'viewport': {'northeast': {'lat': 36.0754717302915,
#       'lng': -86.9200765197085},
#      'southwest': {'lat': 36.0727737697085, 'lng': -86.92277448029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'bp',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1082,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109832105320595149556">Brad The Volfan</a>'],
#      'photo_reference': 'ATtYBwKY0ll5AZieokFtToB2CkvOYQVOtQ2ysnaa4EdYkqIMXDRsccJrlXyNMm87iKDa_dCXTlTXv3lYyuYjKOXoux2L6c84X1pJtCvxu9-vJAb1iREpXRxZ72xlJV5U1J6_p38xjVRjUmjGbvqE0UDHdjeQl1IvvWVK5vwnweTobMVy8Zk-',
#      'width': 750}],
#    'place_id': 'ChIJN8ek9txjZIgR7PBXyiiqe38',
#    'plus_code': {'compound_code': '33FH+HF Nashville, TN, USA',
#     'global_code': '868M33FH+HF'},
#    'rating': 3.2,
#    'reference': 'ChIJN8ek9txjZIgR7PBXyiiqe38',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'finance',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': '7101 Memphis-Bristol Hwy, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.0745327, 'lng': -86.9238781},
#     'viewport': {'northeast': {'lat': 36.07588038029149,
#       'lng': -86.9224497197085},
#      'southwest': {'lat': 36.07318241970849, 'lng': -86.9251476802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Champion Car Wash',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104062189419194614313">Champion Car Wash</a>'],
#      'photo_reference': 'ATtYBwJC5lZyx-e9eOLL0JNxqdTjUYGu59Mht2zYGf1jx8bxAkx-wTUYXqNrvpfhZeDLnx8lc4W9YZPIMiXmccDTpCbw9NtSthnSrjoLjGrYEo-xxPUIuCGD3Ewf4dhFOnYxAJPF3gyvFzYH9aCn7vm5cVj0S13R3tlLJjlWeF0ksTEuw7ln',
#      'width': 1242}],
#    'place_id': 'ChIJIZdnX0CIZIgRiMTBgTm6C08',
#    'plus_code': {'compound_code': '33FG+RC Nashville, TN, USA',
#     'global_code': '868M33FG+RC'},
#    'rating': 3.9,
#    'reference': 'ChIJIZdnX0CIZIgRiMTBgTm6C08',
#    'scope': 'GOOGLE',
#    'types': ['car_wash', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 229,
#    'vicinity': '7128 Highway 70 South, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.0875431, 'lng': -86.6928983},
#     'viewport': {'northeast': {'lat': 36.0888538802915,
#       'lng': -86.69152431970849},
#      'southwest': {'lat': 36.0861559197085, 'lng': -86.6942222802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png',
#    'name': 'Shell',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJiUkmdvhuZIgRSrdDJyVFUVo',
#    'plus_code': {'compound_code': '38Q4+2R Nashville, TN, USA',
#     'global_code': '868M38Q4+2R'},
#    'price_level': 2,
#    'rating': 1.4,
#    'reference': 'ChIJiUkmdvhuZIgRSrdDJyVFUVo',
#    'scope': 'GOOGLE',
#    'types': ['gas_station',
#     'atm',
#     'car_wash',
#     'convenience_store',
#     'finance',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': '1277 Antioch Pike, Nashville'}],
#  'status': 'OK'}

# %%
name_list = []
lat_list = []
lng_list = []
def business_final():
    total_business_info = res['results']
    for business_data in total_business_info:
        business_name = business_data['name'] 
        business_lat = business_data['geometry']['location']['lat']
        business_lng = business_data['geometry']['location']['lng']
        name_list.append(business_name)
        lat_list.append(business_lat)
        lng_list.append(business_lng)
name_list = []
lat_list = []
lng_list = []
business_final()

df = pd.DataFrame(list(zip(name_list, lat_list, lng_list)), 
               columns =['company', 'lat', 'lng'])
df
# Out:
#                          company        lat        lng
# 0     Executive Travel & Parking  36.145907 -86.669554
# 1                             bp  36.305003 -86.616900
# 2   Shur Brite Hi Speed Car Wash  36.152997 -86.795001
# 3                Mister Car Wash  35.987642 -86.545082
# 4         White Bridge Auto Wash  36.138586 -86.857295
# 5                             bp  36.109491 -86.923023
# 6      D & T Truck Wash & Repair  36.016063 -86.616702
# 7                             bp  36.183803 -86.610005
# 8                             bp  36.086128 -86.648648
# 9                          Shell  36.156657 -86.806903
# 10                         Shell  36.208675 -86.778131
# 11         Auto Spa of Nashville  36.147678 -86.792647
# 12               Mister Car Wash  36.202449 -86.739376
# 13        Camel Express Car Wash  36.243118 -86.757530
# 14                         Shell  36.117392 -86.922831
# 15               Mister Car Wash  36.083936 -86.727197
# 16      Premier Mobile Detailing  36.077543 -86.731578
# 17                            bp  36.073933 -86.921359
# 18             Champion Car Wash  36.074533 -86.923878
# 19                         Shell  36.087543 -86.692898

# %%
name_list = []
lat_list = []
lng_list = []
def business_final():
    total_business_info = res['results']
    for business_data in total_business_info:
        business_name = business_data['name'] 
        business_lat = business_data['geometry']['location']['lat']
        business_lng = business_data['geometry']['location']['lng']
        name_list.append(business_name)
        lat_list.append(business_lat)
        lng_list.append(business_lng)
        
    while "next_page_token" in results:
        params['pagetoken'] = results['next_page_token'],
        res = requests.get(endpoint_url, params = params)
        results = json.loads(res.content)
        places.extend(results['results'])
        time.sleep(sleep_sec)
    return places
name_list = []
lat_list = []
lng_list = []
business_final()

df = pd.DataFrame(list(zip(name_list, lat_list, lng_list)), 
               columns =['company', 'lat', 'lng'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-251aff5397bd> in <module>
#      16 business_final()
#      17
# ---> 18 while "next_page_token" in results:
#      19         params['pagetoken'] = results['next_page_token'],
#      20         res = requests.get(endpoint_url, params = params)
#
# NameError: name 'results' is not defined

# %%
def search_places_by_coordinate(location, radius, types, api_key, sleep_sec = 2):
    endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    places = []
    params = {
        'location': location,
        'radius': radius,
        'types': types,
        'key': api_key
    }
    res = requests.get(endpoint_url, params = params)
    results =  json.loads(res.content)
    places.extend(results['results'])
    time.sleep(sleep_sec)
    while "next_page_token" in results:
        params['pagetoken'] = results['next_page_token'],
        res = requests.get(endpoint_url, params = params)
        results = json.loads(res.content)
        places.extend(results['results'])
        time.sleep(sleep_sec)
    return places
